# %%
# import libraries 

import numpy as np
import pandas as pd
import re

# %%
# load the data

df = pd.read_csv('C:/Users/TOSHIBA/Downloads/messy_data.csv')
df
# Out:
#        Unnamed: 0                                    ID  \
# 0               0  1e407ff9-6255-489d-a0de-34135d4f74bd
# 1               1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2               2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3               3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 4               4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90
# ...           ...                                   ...
# 10995        6523  07c223be-03e6-4f70-a2b5-86df778cc61a
# 10996        9785  da8a6bbc-5026-4630-848d-f64e80dac56c
# 10997        7826  ed19c966-d6d8-4047-b410-b6e595a39340
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
# 10999        7107  fc25a38a-5747-46eb-b6d3-7173f8255809
#
#                           Name   Age                      Email   Join Date  \
# 0                Hunter Thomas  25.0         xlopez@hotmail.com         NaN
# 1                 Jeremy Irwin  90.0            Jillian Jenkins  2022-07-07
# ...

# %%
#INSPECT THE DATA

# %%
df.head()
# Out:
#    Unnamed: 0                                    ID                     Name  \
# 0           0  1e407ff9-6255-489d-a0de-34135d4f74bd            Hunter Thomas
# 1           1  379f55b8-87d5-4739-a146-7400b78c24d1             Jeremy Irwin
# 2           2  18261368-dfa1-47f0-afc6-bddf45926b07  Jennifer Hammondquickly
# 3           3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5          Sydney Taylorso
# 4           4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90                Julia Lee
#
#     Age                    Email   Join Date    Salary   Department
# 0  25.0       xlopez@hotmail.com         NaN   88552.0        Sales
# 1  90.0          Jillian Jenkins  2022-07-07  139227.0          NaN
# 2  66.0          jscottgreen.biz  2023-11-21   65550.0  Engineering
# 3  39.0       luke56gonzalez.com  2021-11-05  139932.0     SupportJ
# 4  71.0  figueroakayla@yahoo.com         NaN  143456.0    Marketing

# %%
df.tail()
# Out:
#        Unnamed: 0                                    ID                Name  \
# 10995        6523  07c223be-03e6-4f70-a2b5-86df778cc61a                 NaN
# 10996        9785  da8a6bbc-5026-4630-848d-f64e80dac56c    Steven Armstrong
# 10997        7826  ed19c966-d6d8-4047-b410-b6e595a39340  Stephanie Riossell
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e      Bonnie Benitez
# 10999        7107  fc25a38a-5747-46eb-b6d3-7173f8255809      Caroline Ochoa
#
#         Age                      Email   Join Date         Salary Department
# 10995   NaN                        NaN         NaN            NaN        NaN
# 10996  38.0           molly89gmail.com  2021-06-24            NaN      Sales
# 10997   NaN  robert96@pollard-frye.com  15/08/2006  122609.594149         HR
# 10998  37.0         roypark@warren.net  2020-10-09  147322.005171    Support
# 10999  53.0          cdavis@hodges.com  2023-08-10  149224.000000    Support

# %%
df.size
# Out:
# 88000

# %%
df.shape
# Out:
# (11000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11000 non-null  int64
#  1   ID          11000 non-null  object
#  2   Name        8667 non-null   object
#  3   Age         9253 non-null   float64
#  4   Email       9731 non-null   object
#  5   Join Date   8808 non-null   object
#  6   Salary      8761 non-null   float64
#  7   Department  8745 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 687.6+ KB

# %%
df.describe()
# Out:
#          Unnamed: 0          Age         Salary
# count  11000.000000  9253.000000    8761.000000
# mean    5012.947818    54.162650   89886.585012
# std     2884.739158    21.072919   34896.320117
# min        0.000000    18.000000   24655.136613
# 25%     2509.750000    36.000000   59723.844874
# 50%     5024.500000    54.000000   89241.000000
# 75%     7510.250000    72.000000  119491.000000
# max     9999.000000    90.000000  176156.206747

# %%
#HANDLE MISSING VALUES

# %%
#checking for missing values

df.isnull().sum()
# Out:
# Unnamed: 0       0
# ID               0
# Name          2333
# Age           1747
# Email         1269
# Join Date     2192
# Salary        2239
# Department    2255
# dtype: int64

# %%
#removing rows with any missing values
df1 = df.dropna()
df1
# Out:
#        Unnamed: 0                                    ID  \
# 2               2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3               3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 5               5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c
# 6               6  c4892dbb-2554-4ce1-8f11-f6597d7f6782
# 9               9  d06f507d-62e5-4bd6-a252-4e60e109d324
# ...           ...                                   ...
# 10990        3317  10c26512-ce3a-4387-b71a-47768503562e
# 10991        9603  612011e6-101d-4ee2-bbca-16a5056d8217
# 10993        9510  796f8c0b-15a4-475c-bb02-ac892df0c746
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
# 10999        7107  fc25a38a-5747-46eb-b6d3-7173f8255809
#
#                           Name   Age                         Email  \
# 2      Jennifer Hammondquickly  66.0               jscottgreen.biz
# 3              Sydney Taylorso  39.0            luke56gonzalez.com
# 5                  Lisa Bailey  81.0  milleryvonne@fowler-york.com
# ...

# %%
df1.isna().sum()
# Out:
# Unnamed: 0    0
# ID            0
# Name          0
# Age           0
# Email         0
# Join Date     0
# Salary        0
# Department    0
# dtype: int64

# %%
#REMOVE DUPLICATES

# %%
# check for duplicate rows
df1.duplicated()
# Out:
# 2        False
# 3        False
# 5        False
# 6        False
# 9        False
#          ...
# 10990    False
# 10991    False
# 10993    False
# 10998    False
# 10999     True
# Length: 6036, dtype: bool

# %%
#drop duplicates
df2 = df1.drop_duplicates()
df2
# Out:
#        Unnamed: 0                                    ID  \
# 2               2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3               3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 5               5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c
# 6               6  c4892dbb-2554-4ce1-8f11-f6597d7f6782
# 9               9  d06f507d-62e5-4bd6-a252-4e60e109d324
# ...           ...                                   ...
# 10989        5620  4d450808-7caf-432e-bf65-385e715b43fe
# 10990        3317  10c26512-ce3a-4387-b71a-47768503562e
# 10991        9603  612011e6-101d-4ee2-bbca-16a5056d8217
# 10993        9510  796f8c0b-15a4-475c-bb02-ac892df0c746
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
#
#                           Name   Age                         Email  \
# 2      Jennifer Hammondquickly  66.0               jscottgreen.biz
# 3              Sydney Taylorso  39.0            luke56gonzalez.com
# 5                  Lisa Bailey  81.0  milleryvonne@fowler-york.com
# ...

# %%
#CORRECT EMAIL FORMATS

# %%
#define a function to correct email
def correct_email(email):
    # Replace spaces with nothing
    email = email.replace(" ", "")
    
    # check if an @ is present,if not adds domain 
    if "@" not in email:
        if "gmail.com" in email:
            email = email.replace("gmail.com", "@gmail.com")
        elif "yahoo.com" in email:
            email = email.replace("yahoo.com", "@yahoo.com")
        elif "hotmail.com" in email:
            email = email.replace("hotmail.com", "@hotmail.com")
        elif ".info" in email:
            email = email.replace(".info","@gmail.com")
        elif ".biz" in email:
            email = email.replace(".biz","@gmail.com")
        elif ".com" in email:
            email = email.replace(".com","@gmail.com")
        else:
            email+="@gmail.com"
    return email

df2.loc[:,'Email'] = df2['Email'].apply(correct_email)

# %%
df2
# Out:
#        Unnamed: 0                                    ID  \
# 2               2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3               3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 5               5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c
# 6               6  c4892dbb-2554-4ce1-8f11-f6597d7f6782
# 9               9  d06f507d-62e5-4bd6-a252-4e60e109d324
# ...           ...                                   ...
# 10989        5620  4d450808-7caf-432e-bf65-385e715b43fe
# 10990        3317  10c26512-ce3a-4387-b71a-47768503562e
# 10991        9603  612011e6-101d-4ee2-bbca-16a5056d8217
# 10993        9510  796f8c0b-15a4-475c-bb02-ac892df0c746
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
#
#                           Name   Age                         Email  \
# 2      Jennifer Hammondquickly  66.0         jscottgreen@gmail.com
# 3              Sydney Taylorso  39.0      luke56gonzalez@gmail.com
# 5                  Lisa Bailey  81.0  milleryvonne@fowler-york.com
# ...

# %%
df2['Email']
# Out:
# 2               jscottgreen@gmail.com
# 3            luke56gonzalez@gmail.com
# 5        milleryvonne@fowler-york.com
# 6                pperkins@hotmail.com
# 9            denisemaynard@jordan.com
#                      ...
# 10989                luis19@gmail.com
# 10990                 rmccoy@hall.com
# 10991             jpatterson@wise.org
# 10993         MichaelWalker@gmail.com
# 10998              roypark@warren.net
# Name: Email, Length: 5977, dtype: object

# %%
#CLEAN NAME FIELDS

# %%
#cleaning names

def correct_name(name):
    # Remove titles using regular expressions
    name = re.sub(r'^(Mr\.|Mrs\.|Dr\.)\s*', '', name)
    # Split the name into parts
    parts = name.split()
    if len(parts) < 2:
        return name  # return the name as is if it doesn't have at least two parts
    first_name = parts[0]
    last_name = parts[1]
    # Remove any glued extraneous words from the last name
    pattern = r"\b\w+$"
    last_name = re.sub(pattern," ",last_name)
    cleaned_name = f"{first_name} {last_name}"
    return cleaned_name
# Apply the cleaning function to the Name column
df2.loc[:,'Name'] = df2['Name'].apply(correct_name)

# %%
df2['Name']
# Out:
# 2        Jennifer
# 3          Sydney
# 5            Lisa
# 6        Patricia
# 9             Jay
#             ...
# 10989     Richard
# 10990    Kimberly
# 10991     Jeffrey
# 10993     Shelley
# 10998      Bonnie
# Name: Name, Length: 5977, dtype: object

# %%
#STANDARDIZE DATE FORMATS

# %%
# convert the dates into required format
df2.loc[:,'Join Date'] = df2['Join Date'].str.replace('/', '-')

def convert_dates(date_str):
    try:
        # First, attempt to parse with day-first
        return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%Y-%m-%d')
    except ValueError:
        try:
            # If day-first fails, attempt to parse with year-first
            return pd.to_datetime(date_str, format='%Y-%m-%d').strftime('%Y-%m-%d')
        except ValueError:
            # If both parsing attempts fail, return None
            return None
df2.loc[:,'Join Date'] = df2['Join Date'].apply(convert_dates)

# %%
df2['Join Date']
# Out:
# 2        2023-11-21
# 3        2021-11-05
# 5        2016-10-15
# 6        2020-09-17
# 9        2022-12-08
#             ...
# 10989    1982-05-01
# 10990    2020-06-11
# 10991    2021-08-05
# 10993    1992-12-25
# 10998    2020-10-09
# Name: Join Date, Length: 5977, dtype: object

# %%
#CORRECT DEPARTMENT NAMES

# %%
df2['Department'].unique()
# Out:
# array(['Engineering', 'SupportJ', 'SupportE', 'HR', 'HRC', 'SalesA',
#        'Marketing', 'Engineeringi', 'Salesw', 'Sales', 'SalesK',
#        'MarketingU', 'Salesi', 'HRa', 'Support', 'Supporty', 'SalesN',
#        'Marketinge', 'MarketingR', 'HRv', 'SalesM', 'EngineeringL',
#        'MarketingQ', 'HRs', 'Supportj', 'Salesd', 'Engineeringj',
#        'SalesU', 'HRO', 'MarketingH', 'Salesj', 'Saleso', 'Engineeringe',
#        'Marketingr', 'Engineeringm', 'SalesW', 'HRz', 'Engineeringp',
#        'EngineeringS', 'EngineeringT', 'SalesC', 'SalesB', 'Marketingn',
#        'EngineeringK', 'HRo', 'SupportB', 'HRi', 'Supporta', 'HRn',
#        'SupportC', 'Supportm', 'Supporto', 'EngineeringH', 'Marketingw',
#        'EngineeringM', 'Salesy', 'HRE', 'Marketingm', 'HRw', 'Marketingo',
#        'Supportk', 'SupportS', 'EngineeringD', 'Marketingz', 'MarketingI',
#        'MarketingL', 'Salesr', 'Engineeringn', 'MarketingO', 'SalesF',
# ...

# %%
# defines a list of job titles
job_titles = ['Engineering','Support','HR','Sales','Marketing']

#check the dept string starts with one of the job titles in the list, it assumes that's the main job title and returns it.
# if no match is found in the list, it returns the original dept string
def clean_job(dept):
    for title in job_titles:
        if dept.startswith(title):
            return title
    return dept

df2.loc[:,'Department'] = df2['Department'].apply(clean_job)

# %%
df2['Department']
# Out:
# 2        Engineering
# 3            Support
# 5            Support
# 6                 HR
# 9                 HR
#             ...
# 10989             HR
# 10990      Marketing
# 10991        Support
# 10993             HR
# 10998        Support
# Name: Department, Length: 5977, dtype: object

# %%
#HANDLE SALARY NOISE

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# ID             object
# Name           object
# Age           float64
# Email          object
# Join Date      object
# Salary        float64
# Department     object
# dtype: object

# %%
# format column toi display whole numbers
df2.loc[:,'Salary'] = df2['Salary'].apply('{:.0f}'.format)

# %%
df2['Salary']
# Out:
# 2         65550
# 3        139932
# 5        123018
# 6         77311
# 9         37702
#           ...
# 10989    103005
# 10990     60951
# 10991     50511
# 10993     47809
# 10998    147322
# Name: Salary, Length: 5977, dtype: object

# %%
df2
# Out:
#        Unnamed: 0                                    ID        Name   Age  \
# 2               2  18261368-dfa1-47f0-afc6-bddf45926b07  Jennifer    66.0
# 3               3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5    Sydney    39.0
# 5               5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c      Lisa    81.0
# 6               6  c4892dbb-2554-4ce1-8f11-f6597d7f6782  Patricia    66.0
# 9               9  d06f507d-62e5-4bd6-a252-4e60e109d324       Jay    44.0
# ...           ...                                   ...         ...   ...
# 10989        5620  4d450808-7caf-432e-bf65-385e715b43fe   Richard    58.0
# 10990        3317  10c26512-ce3a-4387-b71a-47768503562e  Kimberly    54.0
# 10991        9603  612011e6-101d-4ee2-bbca-16a5056d8217   Jeffrey    72.0
# 10993        9510  796f8c0b-15a4-475c-bb02-ac892df0c746   Shelley    79.0
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e    Bonnie    37.0
#
#                               Email   Join Date  Salary   Department
# ...

# %%
df2.to_csv("cleaned_dataset.csv",index = False)
